# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import pytesseract

# %%
loader = UnstructuredPDFLoader(
    file_path="../data/2025년+건강검진사업안내.pdf",
    mode="elements",
    strategy="ocr_only",
    languages=['kor'],
)

# %%
docs = loader.load()

# %%
len(docs)
# Out:
# 779

# %%
[doc.page_content for doc in docs]
# Out:
# ['SAMSUNG',
#  'A Journey Towards Sustainable Future',
#  'ey Towards',
#  'nable Future',
#  '2025',
#  'Our Company',
#  'CEO 메시지 기업',
#  '소통',
#  'Principle',
#  '푼다 ㅎㅎ',
#  '= 2025',
#  '04 05 06 07 09',
#  '59',
#  'Planet',
#  '[DX#2]',
#  'y+ ws 건 00 or Ho 0',
#  'rior 푸',
#  'i me',
#  'Facts & Figures',
#  'People 임직원 71 21 공급망 12 22 16 27 18 수자원 29 제품 안전 20 32 Appendix 62 독립된 76 63 Scope 1,2 배출량 AS 의견서 77 68 56006 3 배출량 검증 의견서 78 72 GRI Index 80 TCFD (HAE 82 SASB 대조표 84 About This Report 86',
#  'Our Company Planet People Principle Facts & Figures Appendix',
#  '35 45 51 53 55',
#  '“2 4 02 7',
#  ': Our Company',
#  'CEO 메시지 04 05 기업 06 평가 07',
#  '소통 09',
#  'Message from Our CEO',
#  'CEO 메시지',
#  "글로벌 시 의 성장 등 급격한 AAS] Solutions)#SE INS SRS 또한 자립 ' 겪은 한 해 산업계 전 에 한 더 BALA 통합 시 Regenerative Catalytic System) SIBCIIS' HSL SAA HMMS 총 있으며, 새로운 사업 전 큰 EAST 있습니다. 국내 . 을 더 있습니다. Alliance for Water Stewardship)2 2 4E} 많은 지원할 이러한 전년 대비 매출 치구 드라이 BAPISS 저때 글로벌 UL 이어 올해 고 글로벌 공시 규제 달하는 전략적 강화 등 Solutions NA SCH 매립 Waste to 맞춰 동안 회 지속 다지는 데 ㄴ 87011) 최고 등 경영 전략 이행 활동, 성과 등 충실히 다양한 분 이러한 LAS 첨단 따른 에너지 더욱 긴밀히 주신 결과, 브랜드 평가 도전 있습니다. 특히 급속한 다지기 위해 지속 기준 사상 첫 SAS 연속 글로벌 sole mrp 으로 등에서 에너지 탄소 크게 main 있습니다. 최고의 MBAS 받았습니다. 있습니다. SOAS 탄소 발자국 TEA 에너지 기술 들 맞춰 친환경 에너지 활용 운 미래 - 위한 확실한 DAIS} 다양한 기울이고 다지고 새로운 미래 = 2 a AL 다양한 기울이고 있습니다. 충실한 성장 기반 0 a 있습니다. : 느 르 S19] off 1 이러한 사의 에서는 예방 위해 늘 기울이고 있으며, + 다라 위해 사회 다양한 있습니다. LTIR(Lost-Time Injuries Rate) Global Top Tier nue 앞으로도 성장 AIMS 다하겠습니다. 관리 있습니다. 부문 환경 대해 먼저 말 9 so 대해 a ee sens San ¥i AAMAS 대해 리스크 B7HBusiness & Human 흰 순환 = veo = 기반 무브 르드 극대화, 그리고 기술 Rights Benchmark) S 관련 통한 환경 난제 HSS 위해 있습니다. 부회장 Dx{Device experience) 080K EIAKE! SG SHE 7004 THU LOHAN 위해 254 Ce vot evice eXperience) #2 =k. 2 = 녀 기준 때 44471 MLOILaNe 전하 대요 Ot SSS 글로벌 공급망 규제 a 1 EA 95.2071 DES, AE 제품 고효율 에너지 ASH 대비 평균 31.5% 0 ： > 플라스틱 분이 재활용 AMS O|SISLICE 지원해 청년 소프트웨어 ICH OFLC",
#  '2025 = OurCompany Planet People Principle Facts & Figures Appendix 42) 4 04 D>',
#  'About Us',
#  'ㅁ',
#  'oo nn “ eee 최고의 글. , 삼 임',
#  '삼 wag XAOPRAYS THO OS 모든 삼고 있습니다 앞으로도',
#  '이를 위해 을',
#  '소개 품 및 글로벌 네트워크',
#  '전 따라 Dx(Device experience)2t DS(Device Solutions) 나뉘어 SYST 있습니다. 네트워크 시스템, 컴퓨터, TV, 냉장고, 세탁기, 에어컨, 등 있으며, 메모리 사업, Foundry 사업, System LS! DRAM, NAND Flash, 반도체 말 기준 MAG R&D 센터, 디자인 센터 SS 있습니다.',
#  '매출 매출',
#  '174=8,87749 1529452 주요 사업부 D X D S 주요 사업부',
#  '@ 개 Monieexperiencs Device eXperience Device Solutions may hen Foundry ssa',
#  '5 DL 네트워크 EA)',
#  'x 상기 실적 SDC, Harman',
#  '구매 센터 15 109 33 6 0 대비 ^ 기타? 합계',
#  '| 240 40 7 30 임직원 Basia” 250374 35 Oza',
#  '7) SO OE TILE 3) 기업',
#  'At',
#  'Rd Be',
#  '대',
#  'lI 0:',
#  '05 보고서 2025 Our Company Planet People Principle Facts & Figures Appendix 4) 4 D>',
#  'Corporate Governance',
#  '기업',
#  "Ss ATE 주 = 이사회 구성 추진 체계 이 주주 = 이 의 HSS 최고 0%, 주요 있습니다. 21 OFA] ASR DOI 7a A SAS 추진하고 A AEE 객관적인 시 각 ASMS 균형 잡힌 거버넌스 위해 확대 이사회 산하 이사회 산하 SS 통해, 하였습니다. 말 기준 이사 SE! 이행 (ASS, SMS) GES, ASS, RSS | 있습니다. SESH SS (6000008068 정책, 중장기 Ht 등 위하여 이사회 본 보가 13 BOA: —a-. = AQT] 분야별 관련 협의 SUH TBE : 주기: 최소 반기 18] 이싱 더불어 선임 성별, 국적 등 있습니다. 분야별 | Le ro} — ae Al: i oe ” USHE, 재무, BS, ERATED, 리스크 함께 관련 따라 관리, 분야 등에 관한 히야 인권 음질 풍부한 이를 ae was ee eee ee 환경 Hoe 회의, 풍부한 ES 이름 위해 BSM(Board Skills Matri@S 등 주요 주제별 관련 [OSHS] 작성, 또한 0 2 성별 등 이사회 미치는 긍정적 여성 ' = coils 더 ° 2A}. 21 210] 성과 평가 관련 으으 이이 are 이시이 clon 사업 성과 평가 업무 맞게 전환, 제품 개발 준법 제품 접근성 사회 있습니다.",
#  '2025 = OurCompany Planet People Principle Facts & Figures Appendix 42) 4 06 >',
#  'Materiality Assessmen',
#  '평가',
#  '중대한 미치는 주요',
#  '3Y 파악해 우선 SSS SHS WS 평가',
#  'European Financial Reporting Advisory Group)0| 평가 이행 70/4A(Materiality Assessment Implementation Guidance) @Ol SCH B7t(Double Materiality Assessment)S 전기',
#  '기 이후 내 관련된 큰 없다고 최종 중대 FAS SUS',
#  '해당 관련된 외부 미치는 모두',
#  '평가 프로세스',
#  '이애',
#  '대내외 선별',
#  '대내외 환경 분석',
#  '등 공시 질의 사항 등 내부 자료 검토',
#  '[기',
#  '분석',
#  'lA ES FASE 파악 위해 평가',
#  '평가 실시',
#  '식별 근거 마련 준 외부 BA) 등) 때 르르 ㆍ 투자자, 평가사 등) 규모 크기 위 미치는 범위 0 환경 cae 위해 BESS 기간',
#  '파악',
#  '[DX] 광물 채굴, 등 제조',
#  '업스트림 105] 광물 채굴,',
#  "' [DX] 연구 제조, 판매 6",
#  'FASS | [ps] 반도체 cease | [> 콜센터, 소비자',
#  'eS) [DS]',
#  '[기 도출 공시 European Sustainability Reporting Standards)0|',
#  '구성 |',
#  '이슈 회사 연관, 글로벌 평가 기준 | 연계, 동종 업계 주요 분석 평가',
#  '주제 이슈 도출 ESRSO| 주제 상위 선정',
#  '2025',
#  '영향 등 sping BOSS 시점 ㅣ . AGoPIE SS 대비 . 따라 정량적 리스크 관련 잠재적 분류 재무 고려한 리스크 a 4A Bel 외부 aH copie MAAR ACS SSS ASS AM (4) 의견 수렴 고객사 투자자, NGO, 국내외 SEAS 실시 다한',
#  '청취',
#  'Our Company Planet People Principle',
#  '업 활동',
#  '주제 Step 4. 중대 선정',
#  'HES',
#  '이 실 미치는 외부',
#  '분석 분석 경영진 AES 거쳐 이사회 산하',
#  '보고',
#  '| -+- |',
#  '분석 결과',
#  '임직원 공급망',
#  '보안',
#  '제품 안전',
#  'Facts & Figures Appendix',
#  '거버넌스',
#  'YD 4 0 >',
#  '중대 주제 관리',
#  '중대 주제가 미치는 해당 위해',
#  "전 시 UNSDGs 리스크 관리 활동 이사회 산하 : ㆍ 1, 2) 달성 기 FAS 배출 감축, 확대, & OW AT 감독 ㆍ 205044 1,2) 달성 식 외부 F| 각 일 의 글로벌 수자원 환원 ㆍ 수자원 지역별 ——- AWS (Alliance for Water eo) 국내 수립 Stewardship) 인증 취득 범위 확대 저감, ANA 보전 등 종 이상 투자 “OX SE: 제품 플라스틱 품 생산, 제품 수거 체계 운영, 사업장 폐기물 icy 플라스틱 적용 제품 ： Waste To Landfill) ' 원순: 7 2 ge - 획득 99.9% 달성 이사회 인권 기본 원칙, 정책, BM: 보장 56 환경 조성을 위한 개선 지속 안전 방침 등 다양한 기준 수립 - 개선 expose * ‘ a 좋은 임직원 소통 사업 임직원 자사 다양한 인권 프 2 | 관리 ate AY 제도 제공 사업 아니라 HES APE THY 글로벌 구매 등 실시 ser 공급망 확보 다양한 기준 수립 안전 es 근로자 소통 ： 교육 통합 실사 프로세스 운영 . 아카데미 운영 CPO(Chief Privacy 원칙: 보다 안전하게, 정책 수립 교육 01667) CISO(Chief 선 삼성 녹스, 삼성 녹스 볼트 등 강력한 보안 Information Security Office24 컨트롤 보안 ACH 방향성: ‘Preventing & Hardening, 포털 운영 보안 타워 수행 Prediction, Detection, Response’ 반도체 기술 보안 운영 품질 최고 위한 완벽 서비스 프로세스 운영 ALE 안전성 제품 고객 ery 운영 반하여 고객 S871 BS, BS 의식, 향상 활동 실시 Se 창조, a -Global CS BAECS(Customer 로직 uso) 실천 실천 Satisfaction) | 역할 수행 ose. 산하 통해 컴플라이언스 윤리 최우선 -CPMS(Compliance Program 프로그램 운영, 감독, 활동 투명한 위해 Management System) 7|#t 리스크 부패 리스크 검토 Sg ate",
#  '= 2025 Our Company Planet People Principle Facts & Figures Appendix 4) 4 08 +',
#  'Stakeholder Engagement',
#  'AS',
#  'ASS 있습니다.',
#  '삼 산 성 활 Zo SL 고려한 다양한 소통 전 사업 전략 수립 등 또한 경영 포럼, MEAN, Se 통해 경영 SHS ABS 위해 신뢰 나갈 중요 관심사 채널 활동 고객 품질 ㆍ 제품 정보 제공 ㆍ 조사 반도체 안전성 강화 - 은. 사용 0” - APE 및 주요 WM Fra 、 영향 채널 담당 인력 배치 - Investors Forum 발표 정보 공개 So) & 관리 거버넌스 등) -Non-Deal Roadshows, 650 로드쇼 정책 수립 Aa 성과 공유 9004 투자자 성과 공시 . 의견 수렴 발표 건강한 대화 주기 맞춤형 프로그램 운영 관리 oo NOW 사업부 행사 개선 mee 좋은 일터 AU 소통 설명 등) 윤리) 활동 프로그램 운영 다이어트 프로그램 등) 관리 시스템 지원 개선 지원 fle 개선 . 감촉 간담회 지원 접수 및 해결 사이버 신문고 채용, 활성화 등 구축 등 중소기업 지원 취업 프로그램 고용 등 봉사 등 인근 (삼성 sltlles, 삼성 실시 아카데미 등) 대한 사회적 책임 포함한 44 기업 간담회 경영진 04600 ACEC”, SCC? tS 대한 기여 “NGO 미팅 워크숍 “RBA”, RMP, Q NGO, #3] 신속한 정보 공개 포럼 1) Responsible Business Alliance 4) United Nations Global Compact ky =F ER ‘ 2) Responsible Minerals Initiative 5) Asia Clean Energy Coalition 3) European Partnership for 6) Semiconductor Climate Consortium Responsible Minerals 간접 TES BAH 간담회 협업 중소기업 프로그램 협업 창구 fr 2 컴플라이언스 공청회 전략 등 추진 성과 BEST AAS AAS =| 언론 등 OLAS, 특허, 간담회 성장 전략 품질 반도체 개최 = 2025 OurCompany Planet People Principle Facts Figures Appendix <) 4 09 D>',
#  'Planet',
#  'eeuec.',
#  'fo} =',
#  '세상, 더 나',
#  '= Se',
#  '머나',
#  '매',
#  '매',
#  'Dx',
#  '21',
#  '더 0 여 KF',
#  'z',
#  'RI 바',
#  '로 x0 04 KE',
#  '4',
#  'Kl ith',
#  '22 27 29 32',
#  '마 =',
#  '12 16 18 20',
#  '‘lot',
#  'rail',
#  '수자원',
#  'Governance and Major Progress',
#  '/ /',
#  "이 최고 이사회 산하 티오 그 eek 202414 실적 및 목표 등 환경 관련 주요 BSS 있습니다. se 00409 0 그 00056 oT 이이 = 은 “Scope 1, 2 배출량 “Scope 중장기 WS 아우르는 ABE susan ene 93 0, yes 3589 oa, Pat 12 3 ' . WEE 93.4% : Hate 94% 매년 주요 대체품 CHE aE Aunt 위원회 있습니다. a ~~ | 수립, 이행 과제 발굴, 투자 실시 등 주요 : 사업장 1% 전환",
#  '대한 가지며, 각 관련 SEAR ES HENAN 00 ES 함께 OXSS 있습니다. 202414 ~ 재활용',
#  '고 품 개 ㆍ i ™ 빼 플라스틱 부품 19 으 =? 검증 넘 등급 취득 Of 사업부 및 주요 재활용 검증 플래티넘 등급 취득 연간 Te ‘eee 8004 74 수:',
#  '는 의 관 톤 는 ㆍ 제로 부서 누적 수거 체계 운영 Global 지역별 ~ 환경 사업부 원활한 DX AIS 플라스틱 부품” 재활용 플래티넘 위해 관련 간 있습니다. 플라스틱“ 적용 글로벌 판매 운영, 5 누적 온 있 소재 조직인 매립 검증 ! : : AMES MES AME 위해 있습니다. 수자원 203081 38.6%” 50% 수자원 환원 (국내 사업장 수자원 달성)',
#  '감 제품 DX BS 전환, 고효율 개발, 폐기물 재활용, 수자원 관리',
#  'AWS” 플래티넘',
#  '재활용 7) 배출량 산정 방법론 2019, AR6 적용 등) 2) 모델): O110174(AE120CXYBEK), MIEN I(WD25DB8995B2), TV(KQ75QND900F XkR), SLUE(LS49DG952SKXKR), PC(NP960QGK), AULEZ(SM-S928) 3) 동일 대비 5) 재활용 WA 시스템 환경 리스크 관리 A ^ = : 거버넌스 @ @ 비율 oer 소재 상이 7) 기준 8) Ｌ Solutions 폐기물 검증 진행 9) SANA 실적 검증 완료',
#  '10)',
#  '2025 = Our Company Planet People Principle Facts & Figures Appendix «an p',
#  'Climate Change',
#  '기 변화 Tess | 변 리 - 회 분석 - 식별 Scope 1, 2 WS gy OMPES IFS 관련 주요한 를 더욱 . TCD! A zeta aa ° et er a ee 이에 위해 기후 시나리오 을 수 를 글로벌 동향, 대응 Pn 에너지 있습니다. 또한 rT = Blt ft ets 1702 종양, eoUSsea 로그 “es ~~ 인한 주요 AAAS 다양한 지구 온도 상승 부문 관련된 리스크 Nz 본 AUS TER 다 인한 다양한 Dave Slash aig 7 = 안 SI = waqjseaaoauc |||” BBE 7H 나 LASSE 미치는 주요 위해 시나리오 분석 있습니다. 산정 AO 최소 eens ASBES OS IOS 주요 ATE — we siciony, 내외부 HINO BlPood a 활용할 수 있도록 대응 기후 시나리오 다 91S BSS 있도록 대응 ESS 기후 시나리오 영향 대한 . 영향 S| oc 이이 000" . 고효율 셀비 교체 효율화 등 에너지 절감 활동 전개 피비 57g SESS) 이기태 NTS REIL, ALE 통해 시나리오 분석 = = = o , = 조끼 44 = Me . _ = = ㆍ 잔여 배출량 위한 사업 주요 리스 최종 여 배출량 SS 위한 Sate 관한 협의체, Intergovernmental Panel on Climate Change), 최종 추 기구 International Energy Network for @ oe coeds ae 용하여 확보 추진 Greening the Financial System) 시나리오 주요 물리적 장 모든 주요 전환 뽀 13 확보 추진 주로 미치는 것으로 이니셔티브 참여 주로 미치는 것으로 1) 관련 Force on Climate-related Financial Disclosures) 2) Disclosure Project) @: 전체 AM, 생산, 운송, 사용, 재활용 등 탄소 배출 저감 분석 프로세스 주요 BAS} 관련된 구성 a 리스크 관리 시나리오 분석 물리적 급성 He 홍수 산불 _ Join) Age 기반 ALE 식별 리스크 만성 te 폭염 강수 한마 150 14001, ISO 50001 등 fees ㅣ 증가 운영, 제품 기획, 외부 동향 영향 아즈. 관련 관련 있습니다. 담당 SATA 배출, mae 사용, 기후 기고 가격 인한 비용 = = 시장 Se 전사 공동 SAM 회의, oo ope, suc oun nee aaa “NB 저탄소 대한 고객 선호도 대응 미흡 같은 정기 SAS 통해 글로 we 이슈 HRS SIRES SE ke 4 EEA HIE MUA 증 AOI PLAS 기술 관련 ar 규제 평판 관련 부정적 전사 리스크 관리 통합 관리 기후 저탄소 수요 확대 i) os Xr 관련 중대 경우, 시장 전환 기호 = WOL SBME El Fa —— 탄력성 기후 대응',
#  '= 2025 Our Company Planet People Principle Facts & Figures Appendix <) 4 12 >',
#  '. . nos ctw eioy rus 홍수 저탄소 수요 확대 기 대한 이 DXBES 주요 스 기회 대해 기후 시 저탄소 - 호 도 높아지고 있으며 삐 삐 — Hi t = a x 잠재적 을 하였습니다. a el = a PASE A TAL 저탄소 수 것으로 합니다. % oN Bl Medium DXB EL 이러한 저탄소 수요 현재 사업 se . : . FY 선정 ~ \\ wos 르 사업 을 때, 될 수 있을 i O | vesi _ 은 최신 관련 국제 다양한 과학 기반 은 0 것으로 있습니다. = 히 = iS) (0) 시오 주요 ass vas a i ea ae 38 J seep 지구 온도 2°C 이하 상승 물리적 × ea . oe g. 은 인한 분석 현지 , a DAR ES 인한 분석 eater 연재 으 수 StHS| 우오 구분 기관 시나리오 SSS 수 트는 — 중 따라 SSS 평균값 위한 체계적인 사업장 관리, 견고한 기후 Sarna 이행 비교 분석 ㆍ 0 (저탄소 배출 시나리오) 지속 합니다. 물리적 현재 배출 일부 O 놓은 것으 = 7 리스크 1000" 5502-45 오지 pes niga 일부 인도 높은 것으로 St 사업장 부지 검토 최대 강우량 AS 98888 중심 성장 같은 주변 하천 상황 등 건물 홍수 \' 침수 더욱 것으로 이로 인해 AS, 피해 있습니다 Net Zero 에너지 설비 재고 등 물리적 2 a a a Tors! = 보은 보아 설비, 재고 등 물 터 조짐 mi rl damian 침수 위험 AAS 배수 IEA? Announced 각 공약 인한 매출 등 발생할 있을 것으로 있습니다. 또한 비상 대응 전환 Pledges 충실히 이행 SAS 있습니다. 리스크 Stated Policies 현재 정책 전환 HOO 조사 외부 AOI} 의견 AMS ZZ 기회 46[28702050 전세계 이행 2. 전환 XESS 문헌 조사; 외부 전문가 의견 거쳐 구매 비용 증가 전력 사용 저감, 에너지 사용 확대 NGS 시고 각국 기후 관련 전환 산정 SHES 등 배출량 저감 구매 비용 따른 S AEA = 충실히 이행 등 내부 | 405 시나리오 등 외부 전망 합니다. 또한 정책 변화, Current Policies 현재 정책 유지 추진 sos S zs = . . 1) Intergovernmental Panel on Climate Change 배가 “le oS 4 TSES = 그 결과, au aa 모니 구미 1 판매, 보유 율 조정 3) Network for Greening the Financial System 4) Shared Socio-economic Pathway 구매 비용 증가, 일반 전력 가격 인한 비용 증가 주요 등 : 있습니다. 5) Nationally Determined Contributions 전환 저탄소 수요 확대, 전환 BE SESE, NEA MEAG £8 10H, MON CE SEC! AEA 수요 확대 소재, 생신 _ 주요 중, 구매 비용 증가, 저탄소 _ = _ . _ 이그 1. 물리적 리스크 106 시나리오, 기후 모델링 a . 폐기, 재활용 걸쳐 MELA 만들기 위해 있습니다. . aioe 5 수요 확대 대한 내 같습니다. 세 이음 이이 이이 이이 Sela, He 글로벌 분석 SS 물리적 제품 내 재생 플라스틱 등 제품 노출 홍수, 태풍, 7S, 산불, 구매 비용 증가 SALA 향후 개선 있으며 SmartThings Energy SFA |PCC| 가지 시나리오 유상 할당 Al 절약 SES 통해 사용 있는 리스크 중에서 가장 있습니다. 한국 있습니다: 제품 수명 위해 제품 수리 용이성 3 것으로 대상 향상, 소프트웨어 AAS, 주초 x 2 él 있습 HAG EFA Zz, AR = — A 1) 예측 OS, 국가 기상청 모든 창고 경우, 있습니다. 저탄소 지속 나가는 것이 z — 2 "si 7 매출 기여할 있을 것으로 있습니다. EA 인한 위치한 유상 할당 늘어날 있음 것으로 있습니다 = 뼈 _ 자) z= 한은 ZS: 흐 (이 르 침수 고도 SS J? SACS 인한 문명 비용 앞으로도 inne 따른 sms 기회, 그에 sa eos _ 7 아시아 높게 특히 =e eee! Hehe ese ae',
#  '= 2025 Our Company Planet People Principle Facts & Figures Appendix 4 13 +',
#  '활동 간접 배출 감축 베트남 제 은 RECS 2022 사용 ow Ane ine ze 모든 사용 BAYS 100% —»- MYO] 100% S 전 또한, PPA 제도 Sea Ses _ ㆍ SHES 수 국내 제 PPA 따라 PPAS 확대, 추진할 획 OX#22 20304 SHE 에너지 효율 향상, 에너지 절감, (ower Purchase A pS 인도 멕시코 에너지 전환 등 ae 7 이이 PPAS BSE MMOLX) 츠코 MAGIA Pratetataiet REC 통해 르 인 pee ian 최우선 추진하고 있습니다. 글로벌 aoe a a ie = HOON 사용 100% S 향후 풍력 매년 에너지 사용 BY 수 절감 인한 HA ABS SORE ㅣ PPAR 0" = aaa = = 하느 르 gras Slo! 있으며, 국내 업무용 해 PAS 중남미 브라질 RECS 사용 전환" 중장기 로드맵 ~ a 00 ㆍ i 때 | ofa! 이 CHAP apse! at . 풍력 PPAS 자체 어려운 대해서는 위한 미국 사업장 내 있습니다. 멕시코 츠 5 =, a A , ainda Renewable Energy Certificate)S 사용 HSA, 풍력 PPAS 통해 조성 (x 있습니다. 중남미 MAAS AAS 총 ESSN a ctu 00” 00 oe EEE : _ 100% SSS 위해 PPAS 지속 아니라, FH Pricing) [< 통해 사용 Soo, = 7 녹색 요금 일부 사업장 사업 대상지 인근 기여할 있는 BS 국내 녹색 일부 사업장 내 설치된 eS 비이 우이 이이 이이 이기 이이 Opes 사용 주로 강 해상 인도 풍력 등 PPAS 0 아이 24202 구미, 광주 PPAS 일반 육상 식물 대비 탄소 RECS 사용 있습니다 s| =) = 들 ㅎ il AA 정도 높습니다. EE EES 사업장 전력 사용 절감 나갈 있는 CDR(Carbon Dioxide Removal) ” eae ae <r our -~…- 0 이응) @ 질 소득 증대, 생태계 보호, 보전 등 UN Sustainable Development 대한 © = & 93.1% 93.4% 93.4% 일부 STKE 함께 0689 Gem) 60080',
#  '7) 누적 IS SAI ECMO :',
#  '2024 2022 2020 14.4% 122 (470) (536) 2021 2023',
#  '2025 = Our Company Planet People Principle Facts & Figures Appendix 42) 4 14 7',
#  '소 감축 제품 전과정 은 소재, 제조, 운송, 사용, 폐기, 재활용 등 제품 전 전과정 Life Cycle Assessment}: 원료, 부품 대응 협력 활동 탄소 하기 위해 비롯한 ＊ 제조, 운송, 사용, 에 제품 전 걸쳐 1100, ACEC, 등 국내외 ease PS af 대외 탄소 발생할 수 있는 잠재적 환경 대라 ne BO IRE ONT 업스트림 감축 활동 감축 중장기 @ DX# BS 주력 전과정 시 주요한 안정적인 Heil a PPA 제도 in 상위 90% 이상 cara Hd SS LIS 있습니다. 2024 eee ate! 자오 seaside a Bea ane 추진하고 있습니다. BASCOM AAS 평가 새롭게 PPA 제도 ERS = 2218! 결과, Hoa Deena 매년 - 탄소 MNSe! 당사 전과정 평가 Power Purchase Agreement) 이에 따라 교육 및 있습니다. 또한 관련 150 14040, 150 14044, 베트남 MENGES PPA aes 체결 제도 위해 위해 배출량 우수한 평가 «= SSSR 있습니다. 있습니다 1) te cu BS | ot ee 00000 위한 협력 위해 자가용 SASS 총 138 en Sa ESN 개의 당사" initiative 1) OX, DS 2 전과정 HES ES -RE100 가입 및 Advisory Committee 멤버 참여 전과정 제품 재질, 중량 같은 제품 용수 “ACEC? 멤버 가입, 활동 소비량 전력 사용량 공정 광범위한 참여 제품 HBSS 50006 5 중 가장 큰 합니다. eae” dea bel 참여 제품 간접 줄이기 위해 ATES Tv, Dxt Ge 제품 단위 전과정 평가 60006 DUCD® 참여 냉장고, 세탁기, 에어컨, PC, SLE] 대표 저전력 on 일 때 = =e oe one 11096699030601/600008( Hal SY 성능 모델 대비 평균 고도화 위해 SDP(Sustainability Data Platform)’ 내에 전과정 CEM een ee ear ntette _ ㆍ 평가 자동화 전과정 평가 4) Decarbonizing the Use phase of Connected Devices 30% Ht SEE 74 MEE S| oe WARS Bol CIO M Anglo? 대비 평균 31.5% dee = nd PolicyEngagement ERIE Sire hee by aos terete erence 업계 CEO 간담회, RETOO 기업 MS aE GUN AS Sea aa Sie 본 더 . 기업 PPA 활성화 향후 전과정 자동화 대상 환경 ㆍ 베트남 DPPA 시행령 SIEM 대응 적극 활용할 PPA 활성화 및 제도 개선 건의 16.4% 1) 글로벌 규제, 의무 공시, 고객 등에 위한 DHS ESG 데이터 및 프로세스 플랫폼 2022 2023',
#  '에너지 - 제품 탄소 배출 저감 사례 BTV PCO',
#  '=',
#  'db',
#  '2025 Our Company Planet People Principle Facts & Figures Appendix 4) 4 15',
#  'ular Economy',
#  '00” 고 s 리스크 관리 활동 재활용 를 MSS 수 XH SS 를 인식 > 평가 처리 > 성과 관리 a 소재 확대 추출한 뒤 다시 이를 접근 Sch APSO 있습니다. OXERS 적극 추진하고 있습니다 특히 = | 이 해양 는 심각한 히 운영 원료 ASHE 생산, 사용, 폐기, 제품 위험 Qole MIB AZ| 기술 플라스틱 MPO! 해양 미치는 심각한 AM 확대, MIMS 하 인식 부족 Solo} OX Se 환경 안전 따라 환경 INS 재활용 할 수 있는 배터리 수거 체계 운영, 사업장 폐기물 매립 제로 검증 추진 다양한 원자재, 부품, 제품 제조, 재활용 재활용 비롯해 힌 zo QS 는 2 = = = 나으 lA 있습니다. 또한 MSS 보다 오래 사용할 수 있는 HHS 물류, 사용, 이르는 자원 Nee 줄이고 환경 재활용 적용 있습니다 미치는 합니다. 위해 있습니다. 한편 포함한 MISS 갤럭시 525 플라스틱, 희토류, 강철, 글라스 폐기물 AIS 재활용 외에도 구리, 코발트, 알루미늄 재활용 AMS AAS 있는 AS 기회 위험 그리고 갤럭시 아머 알루미늄 AMS',
#  'ㅇ Lt',
#  '4y 30',
#  'fir',
#  'SI',
#  'or',
#  '과 o& tt for oh',
#  'Fl',
#  '30',
#  'th',
#  '드',
#  'Ti',
#  '기술 재활용 7 @ 소재 확대 SO] 주 as | 폐기물 문제 |} 혁신 개발 See eee eas 갤럭시 오래된 갤럭시 추출한',
#  '및 수 요 재활용 ceca cosh ie 가사 i ce 또한 SALSHL RA ALS 만 0) 어 2), 99 새롭게 @ 재활용 1 Neo QLED 8K TV 내부 위해 재활용 될 있도록 si 7 그라파이트 추출한 재생 그라파이트 0 ey) 014 or HSE 그라파이트 추출한 재생 제품 | WIAYSEA 있는 위험 소재 지속적인 확대 @ @ re Ags 플라스틱 사용량 배출량 위한 환경부 인정 추진 소재 적용 플라스틱 사용량',
#  '그 단위: 만톤) Se 03 Ee 04 ’ 769 연장 ws Y',
#  '수 및 567 ABS 오래 사용할 있도록 제품 내구성 수리 용이성 향상, 처리 409 소프트웨어 업그레이드 지원',
#  '2024 및 각 대한 대응책 성과 관리, @ 당해 15.8 20.2 케어 Care+)S 통해 파손, 대한 마련 실행 SSNS ena 60 = P| EAS THM 2022 2023',
#  'At',
#  '두 re',
#  'It',
#  'ae',
#  '2025 보고서 Our Company Planet People Principle Facts & Figures Appendix 42) 4 16 D>',
#  '위해 포장재 ASS 비닐 x',
#  '3 AMS 제품 환경 SHS',
#  '포장재 사용 사례',
#  '재활용 위해 비롯한 약',
#  '수거 있습니다. 브랜드 분 없이 각 고려해 직접',
#  'SASS 아니라 현지 재활용 협회 또는 전문',
#  '운영',
#  '누적',
#  '만 단위: 690.9 629.7 569.8',
#  '2 599 599',
#  '2022 2023 2024',
#  '사업장 폐기물 관리',
#  '원자재 사용 효율성 SSS 위해 1\\ 모니터 HSS 만드는 프레스 신규 Metal) 스크랩 20% 또한',
#  '총',
#  '전 수 }. 향후 글로벌 판매',
#  '톤 수거 누적 S, 하고 있습니다.',
#  'HAE 수거 체계 운영',
#  '@ 재활용 서비스',
#  'x! OF aly om im',
#  '프로세스',
#  '선별, 파쇄 전처리 거쳐 구르, 알루미늄',
#  'AHS 당사 부품, 사용',
#  'lI a Oz rat ea 건 db',
#  '2025',
#  '줄이고 재활용',
#  '위해 있습니다. 원자재',
#  'BS 높여 부정적인 SSS',
#  'ex',
#  'hi',
#  '사업장 폐기물 매립 제로 검증',
#  '글로벌 폐기물 매립 제로',
#  '하고 최고 SHS 있습니다. 이를 위해 2]',
#  '시멘트 원료, 재생',
#  'iw]',
#  '광주 슬로바키아 OME(MLtO|, 폴란드, 이집트,',
#  '인도네시아, 태국, 미국',
#  '해외: 헝가리,',
#  '환 100%, 골드 95~99%, 실버 90~94%, 인증 80% 이상) (소수점 적용, 인정)',
#  '2)',
#  'Our Company Planet People',
#  '인 DXBEE 202414 HE 환경 환경부 SETA',
#  '| 않은',
#  '=',
#  'a 2',
#  'Oo 0',
#  'OM Mn (은 JO 30 tu 2 oO oh 묘',
#  'va 따 N tr or “Ol',
#  ', 감 품목',
#  '천여',
#  '사내 폐기물 저감 실천',
#  '사내 일회용품',
#  'ro 뽀 |0',
#  '04 te 더 09',
#  '소 교체',
#  '고 처리기 있습니다.',
#  '저감',
#  'ON 32',
#  'a',
#  '함께 DX A',
#  'ot + 뚜',
#  'Ire (ox',
#  'Hl JE ©',
#  '부 lad an 따 ox wo',
#  'AL =',
#  'Hu',
#  're 10 ox',
#  '에 ni we ol',
#  '은 YO] 늘어나고',
#  '22',
#  'nl',
#  'ic}',
#  '띠',
#  '드 =',
#  '2',
#  '2024 추진',
#  '워',
#  'i',
#  'wal',
#  '2 높이고, AE',
#  '요 on I Ol EI ro',
#  '{습니다',
#  '1) 한국, 4B 71)',
#  '내구성 향상',
#  '제품 5 한편 소프트웨어 통해 사용 있습니다. 또한 갤럭시 CRN(Certified Re-Newed)',
#  '제품 색 함께',
#  'Mo rir',
#  'ami',
#  '+',
#  '내',
#  '@',
#  '@ @ @ 갤럭시',
#  'Principle Facts & Figures',
#  'Appendix',
#  '제 2',
#  '17',
#  '>',
#  '대한 사회적 위해 체계적인 수자원 관리, 수자원 환원 사업 추진, 보전 있습니다. 글로벌 사용한 오수, 폐수, 매월 재이용 추진하고 있습니다. 못하고 수자원 환원 통해 있으며, 사업장 인근 위한 다양한 있습니다.',
#  '용수 관리 . 수자원 METIS 통한 절감 재이용',
#  'AWS 수자원 우수성 입증',
#  '환원 . 모든 수자원 사업 보전',
#  'cy',
#  '등 보전 다양한 활동 이행',
#  ', 미세 플라스틱 저감 제품 개발, 모니터링',
#  '관리 리스크',
#  '— AE 매년 수자원 리스. 스트레스 또는',
#  '트레스 또는 수자원 리스크 있는지',
#  '를 등 관리 있습니다. 수자원 수자원 리스크 지역 AAA A(WRI, World Resources Institute)2| Aqueduct Water Risk Atlas 국제 있습니다.',
#  '글',
#  '등 1) Aqueduct Water Risk Atlas 양적 및 질적 데이터, 제도 및 평판 리스크 항목 평가',
#  'ae',
#  '보고서 2025',
#  '더',
#  '물 전 인 등 DX# 22 ts, 홍수, 생태계 불균형 SS 수자원 내 구미, 광주) 3 각 수자원 대한 대응 ay 수립, 있습니다. 7+EO 내어 위해 7tS 사용량, 7s 있습니다. 홍수 대응 사업장 홍수 인증 ASL 예방, 보고 AALS 정기 인도 있습니다. 각 11 취득 비라 회보 스레 REI 8) iS) 븐 ‘i = m 2)UN, AI NGO 및 연구 718 정화 활동 수행, 복원 지원 등 위해 내 아저 ces 영향 구축 총 10',
#  '@',
#  '떠 ia',
#  'tl He',
#  'SEVT, SU(AWS, Alliance for Water',
#  '부터 최고 Stele’S nn AWS',
#  '이 물 유 글로벌 위해 관리, 관리, 수질 위생,',
#  '로 3 플래티넘" ‘BS’,',
#  '유역',
#  '을 기 용수 환원 : 보전 관리 : 내 등 | 수자원 리스크 지역 사업장 현황 수자원 단위 전체 천톤 18,961 15,446 = AS 2,594 2,038 suns sunning 1) WRI Aqueduct Baseline Water Stress 21 High(3) 지하수 수자원 리스크 사업장 수. OVE, SHO), HA, 18047 902 DR =o | DXB SE 체계적인 수자원 WEAN, 모든 S ASSIS 있으며, 추가 높이고 있습니다. 이외에도 조경수, 다양한 수자원 SSS 추진하고 있습니다. ; 수자원 ㅣ 때 > a 용수 용수 a umes 00000 ASE 으으 12,798 1,358 * 대비 MOSS 14.4% 소비량 38.6% Our Company Planet People Principle Facts & Figures Appendix <) 4 18 D>',
#  '수자원 환원',
#  '제품 생산 물 사용한',
#  'Ho',
#  'a = 무 10 고',
#  'fot a 에',
#  "이 깨끗하게 다시 SAMYLICE 하지만 물의 '2",
#  '수 수자원 환원 100% SHE 수자원 환원',
#  '고 00',
#  '물 겪는 도서 국내 해외 각 지역 정부, NGOS 국내 수자원 해외 모든',
#  '인도 사업',
#  '수 글로벌 수자원 환원 있습니다. 또한 산출 발생할 있는 산출 통해 도 AAO 대한 위해 환원 대한',
#  '사업 수자원 환원 실적',
#  '구분 건수',
#  '국내 72 1,009,091',
#  '해외 348,425',
#  '총계 71.357516(38.6%"',
#  '7) DX#S 글로벌 수자원',
#  '= 2025',
#  '그',
#  '>',
#  'im',
#  '에 =',
#  'my re co TA Hr 0 + ot',
#  'ho 2',
#  'fol',
#  '을',
#  '저감 필터',
#  'hijo',
#  'Ss',
#  '수자원 생태계 위해 생태 있습니다. 특히 경남 동시에 인근 SAS 주요 생태계 SSS 위하여',
#  'Our Company',
#  'Planet',
#  'People',
#  '지자체,',
#  '자이 DES as',
#  'wee',
#  '해안가, 였습니다.',
#  '습지 정화',
#  '| 수자원 절감',
#  'NGOS} 함께 수자원 인근',
#  '=',
#  '브라질, 멕시코',
#  'Z 인식 제고 활동',
#  '해 세계 물의 대한 인식 수: 빙하',
#  '위 SS',
#  '을 mo FS ot',
#  '준 학교',
#  '계',
#  'Principle',
#  'eB 쉬운 anise aru 데이터',
#  'Facts & Figures',
#  'Appendix',
#  '부를 구들',
#  '시 RAE = SESESEICES, jes 2425 tink',
#  '를 A apenves',
#  '19',
#  '있게',
#  '>',
#  'Pollution',
#  '활동 전 규제 이 제품 내 고객 관리 체계적인 BONO] 커지고 있습니다. DX Ae = 아는 SoS ab wu ae = pss 군 4 환경 칠 i" 이지은 Z se | eat i 호 - a Seal os an aan 전근 S MASS, HES 인도 등 미칠 수 있는 부정적 위해 글로벌 HA 대한 철저한 사후 관리 ㅋ 자체 관리 통합',
#  '물질 기 하는 이 물질 해 는 이 무 이 개 을 자체 관리 통 수 있습니다. 사내 관리 있습니다. 환경 을 AA 관련 있습니다 관련 리스크: . 모든 제품 부품 내 PABLO 않도록 AMO 관리 SAT 잠재 위험 SAO 대해 사용 수 0000 Sse NS 안 귀에 LSS > 수 히 있습 csi ZO} , 있습니다. 또한 이행 시 보드 om restr 오인 인 24 HVS 수직. OBA HA - _ = 뻐 = 류지 Ben) Bie Sele keer ee 비적 또한 인증 통해 SACHS ASS SHIRL 내 내 함유 쉽게 반드시 SHOES VSO 적극 참여할 있도록 ㆍ 있도록 등 치는 초 x = _ _ _ _ Pe eas 1 미치는 SSS 위해 내부 있습니다. 원재료 받은 관리 연혁 있 AAAS re) IAI a oa a a = CBE 보증서 SS SBE 관리 프로세스 @ 규제 @ 7) ROHS(EU 제품 내 지침), REACH(EU 등록, 평가, 허가, = = = a ; 으시, 히아 FAI ‘ 24 협력 등 EUREACH HIM 환경 준수 OSA 배출 사고 대비 ere ene 인증 때 vache aay USNS 취득한 Dyes 제조 한해 Es 3 5 AIBTAISIY Sega Biel 한해 있습니다. 유출 누출 위해, 법적 준수 관리 강화 레이 아이디 아이지 ex ugzizni sag 이를 있습니다 배출 사고 대비 각 법적 기준 대비 폐수 방류수 분석 수행 높여 인증 프로세스 자체 기준 준수 있으며, 여유 = a 아하 리스크 관리 있습니다. 또한 주요 aa @ [ll 6 6 쇼 고장 등 사고 발생 없도록 DXBSS 사업장 신규 담당자, 공정 배치, 작업 때 있습니다 절차, 작업 조건 SS 경우, 모든 원재료 Eco Paley OA 최종 방류 사내 취급 사외 유역 맞춰 re} pag TT AS ㅠㅠ Thea 1 TT _— 리스크 있습니다 수문, 밸브 측정기, CCTV A 견우 리스크 SAH 경과 영향 요인 통제 Act 1) 정밀 분석 데이터 7) 검토 비상시 즉시 차단할 A a 경우, 리스크 re 가능성 경과 88 요인 통제 수단 ecm Yen 비상시 즉시 차단할 있도록 있습니다. Se 있습니다. 또한 특정 발생 임직원 쾌적한 대기 위해 수도권 발생 가능한 사고 이로 인한 4 za 박정 SIOP 발생 가능한 사고 이로 인한 00000 주관 자발적 Sop 3) 저감 자발적 Srl] 참여 니다',
#  '4)',
#  '=',
#  '02',
#  'st TAY 2025 Our Company Planet People Principle Facts & Figures Appendix 4) 4 20 >',
#  'Governance and Major Progress',
#  '자',
#  '202414 실적 및 목표',
#  '있습니다. 최고 이사회 05 DS 도 ae 및 주요 SES “Scope 1, 2 ： “DSH 2) 달성 전환율 24.8% 전환율 26% 통해 665” 97%0) 개발 97%) AS 수자원 등 있는 대한 중장기 SHS 매년 주요 위원회 있습니다. 20304 = 99 00 TSR = 99,29,',
#  '이 이행 OS 위해 ， . DON! 폴라니 이이 coumonuensige. 등 주요 실무 999% SS yas Ses 있습니다. 배출량 취득 통한 제로 검증 플래티넘 유지 포함한 YY 대해 Ba 사업장 매립 검증 플래티넘 수자원 대한 활동 SHS 이행 있습니다. 수자원 203014 감촉, 전환, Nel 절감 등 환경 임원 wae “SPATE eS SETS “SS UEAESS et ES 및 조직 있습니다',
#  'oaaa 7 (C17) 3H MEAS NOK AER? 508 (471) RU AIA BIR NOx 2B SSE',
#  'DSHS (대기) 획득 = 처리 할수 있는 용존 배출 저감 변경 완료 | ! 이온 분리 농축 및',
#  '안 @ 거버넌스 4) 국내법 기준 8) Cubic Meter',
#  '7) 배출량 산정 방법론 2)069616「2[008 Catalytic System 3) 71S, 화성, 51 대비, 방류수 재이용 등 7)',
#  'Dh Ot',
#  '2025 2 = 서 Our Company Planet People Principle Facts & Figures Appendix 4) 4 7',
#  '02',
#  'te',
#  'ie)',
#  'Climate Change',
#  '리스크 관리 스 : 별 = mus 0" TCFD? 고 변화 Ose Beep: aaa Dias 를 전사 리스크 관리 이 하 바버" 레이버 = _ _ _ _ - 호 향 BO 을 히 Ss 이를 위해 중장기 탄소 감축 로 수 국제 HE ISO 22301 사업 연속성 (30145, ain ae 0 ye asics atch 이출 xo ne = =|= F ee es 1001 하였 ss 2 리스크 감축 있습니다. Business Continuity Management System)S 하여 a= - 변화 때 00 Ty Sy 히 분석, 내외부 Ps a 등 물리적 벽 르 식별 직접 배출량 위한 장 등 물리적 가 규제, 시장 따른 전환 식별, 이 전문가 의견 수렴 및 라운드 이 = 평 고 디 9 등 급성 a a = 덜 적용 중이며, 에너지 확 통한 간접 이를 토대로 ASS 풍수해 등 급성 물리적 리스크 중 만성 리스크 cheap = = 이이 리스크 발생 따라 배출량 AROS 있습니다. 더불어 Scope3 — ISS WS ATE Baths 호가 가가 아가사 아기어 아이디 oe A710), 전환 AAS. 기회 주로 BS 미치는 위해 또한, 마케팅, 영업, 컴플라이언스 등 각 기능별 것으로 x = OT 리스크 관리 따라 글로벌 발생할 수 ~~ ws SEs 내 +, 감축 목표 수 널 리프 스와 따라 IM 발생할 관련 an Climate-related Financial Disclosures) 등 반도체 감축 적극 추진 있는 관련 상시 2) Disclosure Project) 이러한 리스크 관리 대응 on 니이, Slee) Bee. 이이 이이 000 기회 HBO] 줄이기 위해 전과정 Life cycle PT MOT FE ASSIA 대해 최고 구분 기회 . = $< 20202 Assessment) ESM AS 통한 정량적 사업 보브 ae a a —— 소아 배출량 위해 저전력 반도체 a 리스크 ty 18 8 강수 한파 mie oS = = 있습니다 PORE 혁신 7 AS 분석 증가 _ - 인한 AS 신규 사업 히 = logs 배출량 감축 “FESS UE AkS Sh 7iBlaeS Mote Bate Ae 신규 사림 jy MES All clel 4 WSs cB Og 창출, VAY 중요한 DSH BE 리스크 전환 너지 가격 따른 생산 비용 증가 분석 다양한 시나리오 하에서 리스크 저탄소 - 개발 비용 = = 미치는 이를 IB 전환 ® ㆍ 관리 강화 - LNG 연료 사용 절감 ㆍ 전환 추진 사업 잠재적 기후 얼마나 효과적으로 대응할 있는지 평판 관련 부정적 ee 전환 감촉 = = ne 저탄소 수요 ® . 전력 사용 절감 분석 프로세스 a aasaog 7 케테 기출 0 브르 ls ap 크리 으 및 . 업스트림 활동 ———— ESSSearis Sie SSel ene ASE acing 7 PESOU 대한 당사 대응 강화 반도체 제품 탄소 절감 평가 대한 공급망 대응 역량 전과정 프로세스, PCF 시스템 운영',
#  '저전력 위한',
#  '= 2025 Our Company Planet People Principle Facts & Figures Appendix 4) 4 22 +',
#  '사 관련 국제 점',
#  '량 에서',
#  '4o ne ro 4H fo mu m2 2 므 Pall tr on a',
#  'DB,',
#  'rr 모 0g rol = 도 므 bo',
#  'THE 각 위치한 AIO] 수자원 BLS FES',
#  '균형 잠재',
#  'od 2',
#  '고',
#  '모 AL',
#  'ty re',
#  '2',
#  '기 구분 기관 시나리오 설명 이행 SSP“1-2.6 년경 EASE 018 (저탄소 배출 시나리오) 물리적 2050 현재 배출 aj 5 ee 유시, 중심 성장 5505-8.5 시나리오) Net Zero 에너지 Emissions by 이행 IEA” Announced 각국 기후 관련 공약 전환 Pledges 충실히 이행 리스크 Stated Policies 현재 정책 기회 NetZero2050 전세계 이행 각국 기후 관련 공약 NGFS? NDCs? aoe 느는 은 충실히 이행 Current Policies',
#  '1) Intergovernmental Panel on Climate Change 2) International Energy Agency 3) Network for Greening the Financial System 4) Shared Socio-economic Pathway 5) Nationally Determined Contributions',
#  '고 ma 교 교 I> lu 도 Ww x 40 > 00',
#  'rot = a2 on',
#  '묘 Ir my > AY 비',
#  'te moll',
#  '2 o> A Tw lu',
#  'rou J og H wu',
#  '0 oy Lz a lo',
#  'I> fin',
#  '원 oh for',
#  'lo +',
#  'ies',
#  '2. 전환 A 부석',
#  '1) Shadow price of water: Corporate Bonds 물 스트레스 인구수 가치',
#  '발생할',
#  '2028',
#  '건',
#  '중기, 따라 각 A',
#  'ia +',
#  'Wi Highest WHigh i Medium L Low [| Lowest',
#  'ow 모 보',
#  'NI',
#  'fo',
#  'fo o% 08 ne fo',
#  'rm 240',
#  'TC',
#  '을 HU rat ㄷ rb fu > bw HU 24 0: an',
#  'm',
#  'To 따 Lo 무 개 10 toh',
#  '있는 SAS 헌 조사, 외부 전문가',
#  '2050 견 거쳐 산정 SHES 이를 평가',
#  '정 재 에서 HASH 위한 감축 로드맵 등 내부 IEA, NGFS 미치는 것으로 니 외부 전망 그 대한 과, 가격 따른 생산 비용 구매 비용 중 대표적 같습',
#  'fuln Ao',
#  '오 = 12 2 Pal tr 0g 9 19 > 교',
#  '제 및 정책',
#  'et Zero Emissions',
#  '최대 톤당',
#  '은 1066 시나리오, 기후 모델링 데이터, 위치',
#  '보를 글로벌 분석 SS ABS 주요 물리적',
#  '사 수 까지 있습니다. 국내',
#  '시 배출 초과 이에',
#  '미',
#  '또한, 국가',
#  'A',
#  'ON 3',
#  '+.',
#  '| 크 이 시나리오" 및 결과, SSP5-8.5 시나리오 하에서 국내 대비 시나리오 하에서 TESTE S, HBO] 미치는',
#  'f no 그 flO a rir au',
#  'ㅁ',
#  '4o ah',
#  '0 i nue 2',
#  '같이',
#  'ax fo',
#  '정의',
#  'a Oz rat ea 건 db',
#  '2025',
#  '널리 활용. 단 이는',
#  '된다면 것으로',
#  '기 1) Advanced economies with netzero emissions pledges 지역',
#  '목표, 정책',
#  '가 감 및 SYS 있습니다. 이와 모든 기간 HOLA 설비 투자 및 운영 네용 대비 용수 큰 것으로 이는 Heat Be 물리적 잠재적 AMS 있을',
#  'Our Company',
#  '물 사용 및 소비 저감 용수 MOSS',
#  'Planet People',
#  'N =',
#  'oo OS 02 oo 00',
#  '건',
#  '= ju 4 Hi rel] mo 1 8 thy to',
#  '12',
#  '전',
#  'or a in',
#  'mu m 12',
#  '| +> Or ah jo re on “oh 때 숭 NV pin oe AU HW [고 a on 모 rr iy ov {a Tlo',
#  'i=',
#  '부 의 고 [은 rel rh ox Ji jo x2',
#  '수 on 00 OH +H oo',
#  '으 을 무 = it} tow JH cae) ov Joh Ol tO rat H EJ 50 따 드',
#  '에 b co iu = a} rt',
#  'eR',
#  '0 be Jz bs',
#  'ol',
#  '000',
#  'S! Hu re for on ira] xo 따',
#  '내 on =',
#  '7 ra',
#  '또 띠 모모 밌',
#  'ac oF',
#  '때 lo 띠 lo',
#  '| ipa rg 10 Ju',
#  '에 에 0 ox 00 2 =',
#  '으 oF ilo',
#  'Ho 02',
#  'a',
#  'HK',
#  'oz 00 >',
#  'zz 때 BS)',
#  'fi',
#  '또 re on ay',
#  'rh',
#  'U4 c2 00 때 00',
#  '고 에 고 TH! of Jo m ie = tu! ipa',
#  '이',
#  '모 = 00 000',
#  'fo ~ a',
#  '이 | | 고 00 mo >= = 00 ya + = oy 2 00 20 FEI',
#  'tu',
#  'ㄷ',
#  '에 = tt 10 HU rl ‘oH i) x',
#  'ish +',
#  'ol',
#  '을 권 구매 비용 우 동시에, 이를 통해',
#  'tO] 따른 물',
#  '오 에 |> lu ro rir re',
#  'Nou fol',
#  'ful om nu mn mu ol ay a) oh',
#  'Facts & Figures',
#  'Hu mt 분',
#  '화도 = 활동 RCS 처리 과정 사업장 내 연료 위하여 운전 최적화, 폐열 2024 가스 감축 프로젝트 실적 v 회수, 설비 적극 추진 중 특히, 신규 @ 전 =] RATE TR 공업용 수 전 수 수 고 5 고농도 처리 _ OBS APINEISE) ZAR ^ an ae | 아닌 연중 내내 SSS LNG AVS @ 사용 3% 15.238 신규 사업장 폐열 회수 사용 23% cea 결과, 기흥 사업장 폐열 으 될 PFCs 분해 배출 0 버거 LNG 기반 HS 수 있는 지속 @ 도림 이 아니라 폐열 기존 신규 HF Se] . 0 = 폐열 90% 직접 배출 감축 ) Hydrogen fluoride, #814 반도체 LNG 같은 인한 직접 IS 위해 사용량 절감 공정 있습니다. 처리 대폭 있는 Chemical Vapor Depositon) Engineering 폐열 회수 시스템 배출 저감 폐열 PSS 적극 연료 줄이고, 있습니다. 또한 반도체 제조 이를 위해 공정 레시피 소재 있습니다 2050 부산물 감축 레시피 일관된 막질 < _ = = = = LNG7}A 반도체 MHS] = 안정적인 MISO(Minimum I 순환 공급할 US 것으로 exyome Mout Stable Output) |, SION BOM A _ x NF5 사용량 절감 OF NFs CVD NO 사용량 감축 BSS 고전 A 관리 그 결과 대용량 반도체 업계 최초로 ars 있습니다 Ba 대용량 RCSS 중에 있습니다 17H 생산 RCSH 추가 누적 개발 지구 온난화 낮은 있으며, VST 있습니다. 또한 세대 일부 AIBC PFCs AS HHS Sua 위해 PFCs! 처리 DS Cae” S GLAS 왔으며, DSHS 있으며, 총 앞으로도 신규 생산 AIS 물론, 불가능한 ACS 가장 큰 차지하는 CF,” 2025 제외한 기존 RCS 나갈 있습니다. 앞으로도 있는 1) Perfluoro Compounds 다한 이어갈 @',
#  '시 1) Octafluoracyclobutane, IPCC 2) Carbon Terafluoride, IPCC AR6 7',
#  '4 2025 Our Company Planet People Principle Facts & Figures Appendix 4) 24 D>',
#  'wu ~ ot',
#  '=',
#  'hilo',
#  '선 전',
#  '32',
#  'moll a 2 > 00 Ol Pal',
#  '전체 소비',
#  '가동 시간 2',
#  'on mu a=) 00 고',
#  'fol',
#  '드 ol',
#  'Jin',
#  '00 ra 따 Jk > 모 Ho 00 pa 08 rt lo flr flo © 애 00',
#  '높은 우선 가',
#  '개',
#  'J Ja',
#  'xo m3 08 of',
#  'OE on N 은 주',
#  'Ho WN oz fu ol',
#  'xe 세 그 do',
#  'Tor',
#  'of a am o2 am 00',
#  'a slid ell re —',
#  'ral iy > 00 ow',
#  'ilo',
#  'i',
#  '열 회수 따른 전력 절감 예시',
#  '일부',
#  '자연 조도 AAAS 기존 조명',
#  'DSHS 스마트 ABS',
#  '확대',
#  '왁 =',
#  '구역 주간 야간 심야 Oat',
#  '@s7z44y e@ @ e@ ous e',
#  '40% OF! @ 40~60% 7+S @ 60% O14',
#  '주요 지역별 현황',
#  '이후 해외 AAS 100% 있으며, 국내 위해 PPA(Power Purchase Agreement)S 비롯한',
#  '다양한 조달 있습니다.',
#  '이 2024 구분 2022 2023 23.2 24.3 24.8 ALS S(GWh) 5,849 6,569 7184 한국 TISMW PPAS 254M 시화호 PPAS 두 건의',
#  '수 약 [ 국내 연간 620GWh HAS 있게 되었습니다. 국내 사업장 내 Wea 총 4.014\\ 4.5GWh2| AAS 생산, ,805621" 지열 냉난방 있습니다.',
#  '1) Ton of Refrigeration',
#  'Our Company Planet People',
#  '미국 인증서, Renewable Energy Certificate) 구매, 사업장 내 설치, PPAS 사용 100%S',
#  "미국 SA's SA(EPA, Environmenta Protection Agency)22E| 사용 확대 리더십 PAYS 또한 애플, 이베이, 함께 SMW SAYA PPAS 202",
#  '있습니다.',
#  '1)2019 Green Power Leadership Awards for Excellence in Green Power Use',
#  '수 발전 중국 인증서 구매, 사업장 내 ASS SAlopo 사용 100% 관련 시장 YAS 조달 점차',
#  '간접 배출량 DSS 위한 노력 확대',
#  '다 간접 배출량 위한 지속적인 전환 동시에 PELAONLAR|(CFE”) 대한 고객사 위해 있습니다. 특히, 글로벌 위해 한국 정부 등 산업 경쟁력 동시에',
#  '1) Carbon Free Energy',
#  'CFOi8t(Carbon Free Alliance) CARS| 국제 기술 인증 관한 있습니다.',
#  '이행 수단',
#  'Principle Facts & Figures Appendix 4) 4 25 +',
#  '탄소 감축 [도체 제품 탄소 절감 Al LPDDR 의 서버용 모듈 SOCAMM2"S 56006 3 간접 MSS 관리 를 위해 사내 의 aay ages ath 프로세스 개 5 PCle” 5 SSD AS 구체적인 감축 수 실행 을 하여 반도체 제 환경 제품 소 통해 Al 시 맞는 고성능 저전력 있습니다. Scope 5 HBS HS 추진하고 있습니다 ISO 14040, 14044, 14067 하여 전과정 PHS REAM SAAS AS SQNCISAUCPU), 그래픽 치 7 등 다양한 위한 업스트림 감축 활동 Life Cycle Assessment) ZEMAS (GPU) 등 다양한 위한 aaa 와, SE Ist en] 전력 량 간 Sl z= z= FATA 는 원 우송 풍의 요 i Scope 배 위해 업스트림 SSH 중장기 감축 전과정 BE FST 운송, 사용 그리고 SSS 강력한 NPUS 통해 초당 ㅁ Tera 수 감축 이 전 고 회 전 환경 = 수 Scope 3 감촉 이행 전 | 전 환경 Operations Per Second)9| Al 연산 있습니다. OIA 것을 . 7 . 있습니다. AOS 것을 DSHS AA go -, ( os 미세한 EIS 3 이하 방대한 바 포이 Shs 지는 관리 높이기 위해 실무자 경영진 — SHESR STH SAMOS 지으 반도체 미치는 더욱 낮추기 위해 GAA” #591 NAH ASS ASST 산정 개 이름 Say 대상 직접 Meee < SE ott SSoval ASotol SSI 이름 동해 반도체 Coe 등 전력 eas 높일 있는 고객사 제품 뻐 느 재이 _ ee A= 대해 제품 단위 배 저 관리 할 있도록 전용 SS 있습니다 또한 uu mi . we : a an 5 NE SSS SAO] AOaIE Belg 줄이기 Hol 있습니다 i 위 S| SI (KSIA)2t 함께 반도체 업계 LH Scope 3 배출량 AALS 위한 Soon 수자원 등 “e 미치는 평가할 Doraleutine i ioe Module - 7 ee A 있는 환경 위하 eripheral Component Interconnect Express 업계 공통 배출 높은 주요 일대일“. SH AIAN E1810] SERS 스가 아기 사어 ete AlL-Around, Xt ERI Ae! 9 See AS 이스 통해 맞춤형 감촉 SE 있습니다: imam MEE ODA 반도체 @ 이러한 결과, 감촉 목표 및 두 가까이 공급망 감축 활동 반도체 PCF(Product Carbon Footprint) 대응 협력 활동 참여 한층 배출량 자동화 있습니다. 원재료 수급 반도체 기후 이니셔티브 글로벌 콘퍼런스 - 2 a 빼 _ 참여 등 HLS 위하 다양한 LAS 이어가고 위해 연내 MALE} + Cradle-to-Gale AAS “Oe 이를 통해 배출량 관리 SSNS 높이고 있습니다 원자재 에너지 사용량 폐기물 발생량 등 f 배출량 관리 높이고 있습니다 955 었으며, 원자재 에너지 V2.0 Haws BS 2s} 290} Uy 에너지 WE 위한 정력 BLAS 더 감축 활동 및 전과정 평가 데 PCS 소재, 등 반도체 공급망 내 다양한 감축 있습니다. 세부 단위 ELA 제품 생산 BIEN 산업계 추진하고 있습니다 Le i=) Fa 4A DSIRE 기후 Semiconductor 주요 탄소 배출량 저감 ite Climate Consortium)2| 창립 aS 하며 산업 있습니다 또한 자동화 대해 글로벌 —— . 걸친 대응 Scope 워킹 hes a RE100, ACEC’ 그룹 참여 및 00060" 활동 ae ore peo te 데 “SCC, EC? 이사회 활동 및 실무 참여 산업 주요 제품 및 산업 Scope 주요 제품 전과정 니키 7010 09100 1007 713 71118 11: 이: 시이 x wee aie 저전력 반도체 및 공정 3) Energy Collaborative 업계 SAS 매년 저전력 SAS 메모리 반도체 및 다양한 AIH 조사 및 고객 오 was ce }, DSHS 국내외 다양한 반도체 제조사 ae PC, 모바일 등 IT 기기 따른 업계 050 oes ora 개선 업계 Scope 배출량 관리 추진하고 공동 배출량 있습니다 0” : mn 배출량 감촉! : . 기업 PPA 활성화 감축',
#  '망 및 규제 완화 PPA 이용료 확대 건의',
#  'db',
#  '26 2025 = Our Company Planet People Principle Facts & Figures Appendix 4) 4 D>',
#  'Circular Economy',
#  '국내 사업장 폐기물',
#  '리스크 관리',
#  '999% SHS 위해 있습니다. 분리',
#  '폐기물 종류별 이를 Hels',
#  '재활용 p AALS 적합한 MAS 폐기물 가며 전 사업장 통합 매립 Waste To Landfill) 7HO| Bop 있으며, 20 내 가: 사용, 공정 소자',
#  'ok on',
#  '}.',
#  '비 을 que 00 oh 2 re 이 = ob',
#  '년 KI 40 XN Pal 이 for Oh 2 건 re iis 또 311 3 nul tr a ob P=) jo Cc 40 aH',
#  '“ Ay Ee! 00',
#  '부 Se} 4a aia rot 22 19 re on = nu au 7 다 ay N oO N 는 ra 시',
#  'SOF 메 62 ro. 10 매 마 다 000 00 SS 소구 S ne fi = fo a oy 2 > rr mm HU oh oe SS j',
#  '요 32 ra wk gn a 벼 PA rok',
#  'HU = 00 Ol! El zo oly 드 a',
#  '재활용 재활용 AME 적용 제품 종이 및 mane 사용 중이며 앞으로도',
#  '7) 국내 기준',
#  'a Ie 명',
#  '부 인정 하에 발급 0 대해 발급',
#  '재활용 6: 및 폐기물 확대 사내 일회용품 사용 저감 활동',
#  '재이용 확대 순환 자원화',
#  '및 확대 인정 품목 인증',
#  '및 제품 제품 포장재 관리 MASS 케이스 플라스틱 포장재 저감',
#  '= 2025',
#  '있는 = 통',
#  '있습니다. 전문',
#  '은 1 인 iu jor wf 2 al 10 th oo ox 별 a=] N',
#  '0 ot tu',
#  '2 at 페기 ag:',
#  '있습니다. 그',
#  '관리 자문',
#  '있습니다.',
#  '위해 해 폐기물 처 | 현황 여부 점검) 결과, 폐기물 처리 평가 자체',
#  '아오 교번',
#  '폐기물 관리 프로세스',
#  '가사 Owl #2020 정기 점검',
#  '국내 소재 대상 실시',
#  '황도 =o',
#  '°',
#  '부문 국내 사업장 폐기물',
#  '(기흥, 화성, 평택, 천안',
#  '<……',
#  'O 사내 재이용',
#  '폐기물 처리 ee .',
#  'Our Company',
#  '<n',
#  'Planet',
#  'People',
#  'riot od og',
#  '위 be be bol nf do rok P=] mgt 00 뽀 고 42 보 cS) mo 7]',
#  '은 폐기물 사용 소각, 중화, 그리고 폐기물 베러 기울이고 있습니다. 혼합 a 맞는 처리 새로운 폐기물 — MESS 결과, 20244 국내 사업장" 대비 0.6%p 99.0%S NALS, 화성, 평택, 천안, 사내 일회용품 통한 폐기물 모노 사무실 사무실',
#  '그 동',
#  'i]',
#  '10 oo fio io 0',
#  '더',
#  '다 사내 식당, 입점 BS 범위 플라스틱, SW',
#  '‘| 검증 플래티넘 등급 취득 글로벌 UL Solutions',
#  '전 온 제로 로부터 매립 위해 소각 처리해',
#  '폐기물 사업장 제로 등 다양한 이를 UL 매립 검증 최고 전체',
#  '및 플래티넘 유지할 평택, 천안, 온양 SCS, SESS, TSLED, SAS, 5417 2) Waste to Energy: MYCE 소각',
#  'Principle Facts & Figures Appendix <) 4 27 +',
#  '재이용 확대',
#  'CMP(Chemical Mechanical Polishing) 대한 있습니다. CMP 지나면',
#  '분리, 선별, 세정, 용융, 등 재생 공',
#  'as hilo',
#  '» onl',
#  '주',
#  '주 ci',
#  'ASS MOSS 수 있도록',
#  'AS 있도록 순환 시',
#  'CMP 재이용 흐름!',
#  '0 ㆍ 686 9°',
#  'ENA 반출',
#  '08 6',
#  '소재 분리 Recycle PEEK", STS” PEEK&STS 신품 납품',
#  'Recycle Retainer Ring(R/R) =<',
#  '1)Polyetheretherketone . 2) Steel Type Stainless',
#  '존 할 배기 SA SAAS 재사용 수 있는 연',
#  '사용 지난 경우, 불순물 MAS 위한 소성 거치고 선별. 파쇄, 후 품질 거쳐 동일 있습니다.',
#  '배기 재이용 흐름도',
#  '사내',
#  '건식 A',
#  'ae',
#  '2025',
#  '웨이퍼 Tray) 반도체 갤럭시 525',
#  '이와 같이 DSF TAA',
#  '시 제조업 최초 인증',
#  '전 BEA 내 받은 사용한',
#  '을 10% 이상',
#  '웨이퍼 부문 간 있습니다.',
#  '확대',
#  '선순환 만들',
#  '2',
#  '인정 1) IC IC ee _ _ IC 트레이',
#  '경우 폐기물',
#  '를 인 ASST 않는 않는 aca 다. > (트리 CSTE yy cH 발정 SSI BANGS',
#  '0 a 생산 성형 생산',
#  '및 PBT” 복합체) ESS Fake SS 6660 > Peter Se 누적 1 | 되었고, 연간 생산 및 DS 재구매',
#  'fe)',
#  '전부 개정,',
#  '2) Polycarbonate 3) Polybutylene terephthalate',
#  '2022 3,024 2025" 2,243',
#  'Our Company Planet People',
#  '관리',
#  '적 재활용 SSD AE',
#  '제품 제품 포터블 590(50110 State Drive) 17 Shield 해당 TUV" SHE 재활용 소재 OSS 받았습니다.',
#  '1) 대표적인',
#  '재 플 제품 종이 위해 있습니다. 550(50110 State Drive)2) 플라스틱 소재 종이 AMS 포터블 SSD 및 Heatsink 제품, 2.5" 대한 종이 소재 트레이',
#  '환',
#  'al',
#  'me',
#  '포장',
#  'ASS M.2 대하여 확대',
#  '재활용 소재 인증 포장재 확대',
#  '컴포넌트 플라스틱 트레이 내 재활용',
#  '대하여 150 14021 재활용 소재 USS',
#  '받았습니다.',
#  '기관 1) 영국 글로벌',
#  'Principle Facts & Figures Appendix 4) 4 28 +',
#  '반도체 생산 SAO] 따라 용수 것으로 그럼에도 통해 국내 SHS 이를 위해 다양한 기울이고 있습니다.',
#  '먼저 SIS 용수 위해 UO, 사업장 내 용수 MISS 위한 기술 함께 위한 추진하고 있습니다.',
#  '또한 수자원 있어 이에 사업장 OIE 인근 생태계 HSS 증진 있습니다',
#  '용수 , 프로세스 최적화 공정 개선 및',
#  '| 효율 극대화 공정 내 용수 재이용 및 통한 재이용 재이용 도입 추진 관리 증진 활동 2025',
#  '리스크 관리',
#  '부 리 > om = 2 rf og SF it',
#  '따 des Th 8',
#  '수자원 리스크 관리 국제 수자원 리스크 관리 Aqueduct Water Risk Atlas”’S',
#  '자 리스크 결과',
#  '물 수자원 리스크 위한 수자원 Wein 7] 수자원 양적 및 질적 Cole, AIS 및 리스크 SEIS 평가 사업장 스트레스 레벨 Medium-High Extremely high Medium-High Medium-High 리스크 및 대응 전략 >7te, 단수 체계 구축 등 다각화',
#  '회 물 물 환경 법 수자원 + 7he 피해액 산정 스트레스, 수자원 리스크 검토 후 대응 고갈, 오염 물의 날 기념 활동 참여 ~ 소통, 리스크 발생 예방 관련 규제 ie 모니터링,',
#  '적 기준 및 엄격',
#  'ron',
#  're',
#  '리',
#  'Our Company Planet People',
#  'Principle',
#  '리스크 관리',
#  '국내 TNFD(Taskforce on Nature-related Financial Disclosures)7FHAStSA ENCORE(Exploring Natural Capital Opportunities, Risks and Exposure)”, WWF-RFS(World Wide Fund For Nature Risk Filter Suite)’ $3 기업 물리적',
#  '물리적 결과 리스크 중간 등급',
#  '대응 AS 있습니다.',
#  'TUNEPS| AHO! SSA 의존성',
#  '물리적 리스크',
#  '전 ㆍ 사업장: 오염, 토지 이용, 산림 훼손, 외래종 하위 리스크 산정 위치한 지리적 반도체 업종 따라 오염',
#  '5 영향 2|A (Regulating Services-Mitigating) 화성, BANGS: 중간 등급 높음 등급 AS SS 높은 서해안 지리적 낮은 업종',
#  'NI',
#  '저해',
#  '로 10',
#  '00 Bt 뽀 02 FO Jf ol',
#  '낮음 @ @ 중간 @ 높음 @',
#  '»%® WWE-RFS Biodiversity Risk Filter(A|S= 지역:',
#  'Facts & Figures Appendix',
#  '9 40 Ao = = 19 ot +> a 09 lon ou 비 N 요 N Bb it a Ey mm 메',
#  '지하수 143,637 0 취수 예정) 용수 16,759',
#  '009 2 sea!',
#  'ANS MHRA 60,139 v 방류 ot',
#  '56,695',
#  '주 주 00 ou ne oN > = Ss = > 4> 00',
#  'ow on Q Pa S 00 nell rr 00',
#  'of cin tr oo! MYO ilo 고 >H on = Ral 교 moll 2 = 00 oh',
#  '= m2 on 을 = be = ma + Ral ip) no rir re 의 ol XN xo 2 | > to 내 10',
#  'A',
#  '3 00 ot ot',
#  '으 m2 o> 30 or',
#  '인 oh',
#  'Ras 2 on ined £ fal',
#  '때 > on + 또 oe i = 터 므 > ir 08 ook be > for 위 = 모 og o&',
#  'm 12 ol x ie a',
#  'fo on tA L no Me ow = ol',
#  'El = 12 om oe re 꼬 jo',
#  'pac) o> 드 꼬 이 of plo 먼 4> 내 aR oe TQ = mo 고 =',
#  'oe H 2 rah ob 대 | 번개 “on aes 4 rE a lp uo 00 nin',
#  'Je ol 32 10 묘',
#  '1 om [pal [때 0 = [내 z on & 00 2 44 in “io log 0 > a 40 > Ao Ob go El 20 xO Te 『 을 느 tow ol Q Oz mya 모 09 ra a',
#  '+> + 32',
#  '1 = 00 of oy a THe an 내 fe = 12 alld {ye 먼 aM Ss Ss & Lara dr a > a ne xa',
#  '=',
#  'db',
#  '2025',
#  '설비 세정 프로세스 최적화 등 설비 이',
#  '여 용수 있습니다. 데이터 Geis',
#  'EAS 세정 이를 생산',
#  '피 세정 그 i',
#  '시 즉시 가장 위해 있습니다. 용수',
#  '을 2 사업장 기준 용수',
#  '효율성',
#  '국내 사업장 용수 (단위: 천톤) (기흥 화성, 평택, 천안 2022 10,950 2023 12710',
#  '2024 ns 16,759',
#  'Ww 40 00 00',
#  '2 of + 코 =) + Of0 때 a',
#  '있습니다. 용수로 사내 통해 있습니다. 특히 폐수 용수 있으며, 국내 사업장 기준',
#  '2024 국내 사업장 용수 (기흥 화성 2022 85,284 2023 92,657 Cs 101,106',
#  'Our Company Planet People',
#  '수 후 타 있도록 수질 개선',
#  'Recovery Tank Recovery Tank',
#  '기 1) R-RO: Recovery Reverse-Osmosis 3) Neutral Water',
#  '하수 재이용 도입',
#  '인근 환경부, 경기도',
#  '등과 함께 반도체 사업장 물 재이용 맺었고 반도체 사용할 이를 위해 적격성 AES 재이용 AMS 있으며, 2029',
#  '년 공업',
#  '있도록 준비',
#  '23 Alliance for Water Stewardship(AWS) 213 취득 (이',
#  '국내 최초로 Aws 인증 최고 등급',
#  '전 을 평택 사업장, 중국 1A DSHS 국내 플래티넘"',
#  '등급',
#  'AWS',
#  'Principle Facts & Figures Appendix <) 4 30 D>']
