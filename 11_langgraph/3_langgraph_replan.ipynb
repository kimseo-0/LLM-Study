# %%
from dotenv import load_dotenv
from typing import Annotated, TypedDict, Literal, List
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilySearch

# 모델을 두가지
# 컨트롤용 모델 -> gpt-4.1-mini
# 메인 에이전트 모델 -> gpt-4o
llm_ctrl = ChatOpenAI(
    model = "gpt-4.1-mini",
    temperature= 0
)

llm_agent = ChatOpenAI(
    model = "gpt-4o",
    temperature= 0
)

search_tool = TavilySearch(max_results=5)
TOOLS = [search_tool]

# %%
from langgraph.graph.message import add_messages

class State(TypedDict, total=False):
    input : str # 처음 입력하는 사용자 질문

    messages : Annotated[list, add_messages]

    # plan 노드에서 만든 단계별 계획
    plan : str

    # 현재 그래프가 진행중인 단계
    status : Literal["planning", "acting", "replanning", "done"]

    # 현재 몇번째 반복을 진행했는지
    step : int

    # 최대 반복 횟수
    max_iters : int

    # 전체 과정을 log
    log: List[str]

    # 최종 리포트
    report : str

# %%
def _log(st: State, msg: str) -> None:
    # 상태 State 에 실행 로그를 추가하는 
    st.setdefault("log", []).append(msg)

# %%
# 1. Planner 노드 만들어 보기
from langchain_core.prompts import ChatPromptTemplate

plan_system = (
    "당신은 촉나라의 책사 제갈량. IQ 가 240이야. 너는 사람을 잘 구슬려서, 일처리를 효율적으로 진행한다."
    "목표를 달성할 수 있도록 단계적 계획을 5 ~ 7단계로 작성해라"
    "- 각 단계: 목적/행동/산출물/도구필요여부 한줄 요약\n"
)

def planner_node(state : State) -> State:
    user_input = state.get("input", "")

    prompt = ChatPromptTemplate.from_messages([
        ("system", plan_system),
        ("user", f"[목표] : {user_input}\n\n '계획' 섹션만 마크다운으로 작성")
    ])
    res = llm_ctrl.invoke(prompt.format_messages())
    new = {**state, "plan" : res.content, "status" : "planning", "step" : state.get("step", 0)}
    new.setdefault("messages", []).append(res)
    _log(new, "[planner] 계획 설정")
    return new

# %%
planner_node
# Out:
# <function __main__.planner_node(state: __main__.State) -> __main__.State>

# %%
# 2. Agent 노드 만들기
from langgraph.prebuilt import create_react_agent
agent = create_react_agent(llm_agent, TOOLS)

def agent_node(state: State) -> State:
    agent_system = (
        "당신은 코딩/리서치/투자 어시스턴트야. 필요할 때 도구를 호출하고, 많은 내용이 담기면 요약해"
        "너무 많은 말을 하지말고, 다음 행동을 분명히 하도록 해"
    )
    msg = [("system", agent_system), *state.get("messages", [])]
    out = agent.invoke({"messages", msg})
    new = {**state, "status": "acting"}
    new.setdefault("messages", []).extend(out["messages"])
    _log(new, "[agent] 행동/응답")
    return new

# %%
# 3. Tools 노드
from langgraph.prebuilt import ToolNode
from langchain_core.prompts import ChatPromptTemplate

tools_node = ToolNode(TOOLS)

replan_sys = (
    "당신은 리플래너입니다. 직전 도구/에이전트 결과를 분석해서 다음 행동을 지시하세요"
    "충분한 근거가 모였으면, '종료'를 선언"
    "아니면 다음 검색/행동을 지시"
)

def replan_node(state: State) -> State:
    msg = state.get("messages", [])
    res = llm_ctrl.invoke([
        #{"role":"system", "content" : "지금 상태에서 '종료', 또는 다음 행동을 지시해"}
        ("system", replan_sys),
        *msg
        ("user", "지금 상태에서 '종료', 또는 다음 행동을 지시해")
    ])
    text = res.content
    done = ("종료" in text) or ("충분" in text and "근거" in text)
    new = {**state}
    new.setdefault("messages", []).append(res)
    current_step = int(state.get("step", 0)) + 1
    new['step'] = current_step

    return new

# %%
# 마지막 노드
final_system = (
    "지금까지 대화 / 검색 내용을 바탕으로 최종 리포트를 작성하세요"
    "핵심 포인트 -> 리스크 / 기회 -> 참고 자료 요약\n"
)

def final_node(state: State) -> State:
    msg = state.get("messages", [])
    res = llm_ctrl.invoke([
        ("system", final_system),
        *msg
    ])
    new = {**state, "report" : res.content, "status" : "done"}
    new.setdefault("messages", []).append(res)
    _log(new, "[final] 최종 리포트 생성")
    return new

# %%
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import AIMessage

builder = StateGraph(State)

# %%
builder.add_node("planner", planner_node)
builder.add_node("agent", agent_node)
builder.add_node("tools", tools_node)
builder.add_node("replan", replan_node)
builder.add_node("final", final_node)

# %%
# 엣지추가
builder.add_edge(START, "planner")
builder.add_edge("planner", "agent")
builder.add_edge("tools", "replan")

# %%
# 조건부 엣지 연결
def router_agent(state: State):
    msg = state.get("messages", [])
    if not msg:
        return "final"
    last = msg[-1]
    if getattr(last, "tool_calls", None):
        return "tools"
    return "final"
builder.add_conditional_edges("agent", router_agent, {"tools" : "tools", "final" : "final"})

# 리플랜 조건부 엣지
def router_replan(state: State):
    if state.get("status") == "done":
        return "final"
    else:
        return "agent"
builder.add_conditional_edges("replan", router_replan, {"agent" : "agent", "final" : "final"})

# %%
graph = builder.compile()
graph

# %%
input = "로고 디자인을 위한 리서치"

for evt in graph.stream({"messages" : [("user", input)]}, stream_mode="values"):
    for key, value in evt.items():
        print("-"*30, key,"-"*30)
        print(value)
# Out:
# ------------------------------ messages ------------------------------
# [HumanMessage(content='로고 디자인을 위한 리서치', additional_kwargs={}, response_metadata={}, id='f847ba37-52c0-4852-ad82-2b0e8439e1aa')]
# ------------------------------ messages ------------------------------
# [HumanMessage(content='로고 디자인을 위한 리서치', additional_kwargs={}, response_metadata={}, id='f847ba37-52c0-4852-ad82-2b0e8439e1aa'), AIMessage(content='```markdown\n# 계획\n\n1. 목적: 목표 명확화 및 세부 목표 설정  \n   행동: 목표를 구체적으로 정의하고 달성 가능한 세부 목표로 분할  \n   산출물: 명확한 목표 목록 및 세부 목표 리스트  \n   도구필요여부: 필요 (문서 작성 도구)  \n   한줄 요약: 목표를 구체적이고 세분화하여 명확히 한다.\n\n2. 목적: 정보 수집 및 분석  \n   행동: 관련 자료와 데이터를 수집하고 분석하여 상황 파악  \n   산출물: 분석 보고서 및 인사이트 도출  \n   도구필요여부: 필요 (인터넷, 데이터베이스)  \n   한줄 요약: 목표 달성에 필요한 정보를 체계적으로 수집하고 분석한다.\n\n3. 목적: 전략 수립  \n   행동: 수집한 정보를 바탕으로 실행 가능한 전략과 방법론 설계  \n   산출물: 전략 계획서 및 실행 방안  \n   도구필요여부: 필요 (전략 기획 도구)  \n   한줄 요약: 목표 달성을 위한 구체적인 전략을 수립한다.\n\n4. 목적: 자원 및 역할 배분  \n   행동: 필요한 자원과 인력을 파악하고 적절히 배분  \n   산출물: 자원 배분 계획 및 역할 분담표  \n   도구필요여부: 필요 (프로젝트 관리 도구)  \n   한줄 요약: 효율적인 실행을 위해 자원과 역할을 체계적으로 배분한다.\n\n5. 목적: 실행 및 모니터링  \n   행동: 계획에 따라 실행하며 진행 상황을 지속적으로 점검  \n   산출물: 실행 결과 보고서 및 피드백 자료  \n   도구필요여부: 필요 (모니터링 도구)  \n   한줄 요약: 계획을 실행하고 성과를 지속적으로 관리한다.\n\n6. 목적: 평가 및 개선  \n   행동: 실행 결과를 평가하고 문제점을 도출하여 개선안 마련  \n   산출물: 평가 보고서 및 개선 계획서  \n   도구필요여부: 필요 (분석 도구)  \n   한줄 요약: 실행 결과를 평가하여 지속적으로 개선한다.\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 485, 'prompt_tokens': 116, 'total_tokens': 601, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CU9Cu4BiPenEMQfWzP7T9UphpkSUg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6cd2b35e-4840-4827-bbdd-daa0aa714669-0', usage_metadata={'input_tokens': 116, 'output_tokens': 485, 'total_tokens': 601, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# ------------------------------ plan ------------------------------
# ```markdown
# # 계획
#
# 1. 목적: 목표 명확화 및 세부 목표 설정
#    행동: 목표를 구체적으로 정의하고 달성 가능한 세부 목표로 분할
#    산출물: 명확한 목표 목록 및 세부 목표 리스트
#    도구필요여부: 필요 (문서 작성 도구)
#    한줄 요약: 목표를 구체적이고 세분화하여 명확히 한다.
#
# 2. 목적: 정보 수집 및 분석
#    행동: 관련 자료와 데이터를 수집하고 분석하여 상황 파악
#    산출물: 분석 보고서 및 인사이트 도출
#    도구필요여부: 필요 (인터넷, 데이터베이스)
#    한줄 요약: 목표 달성에 필요한 정보를 체계적으로 수집하고 분석한다.
#
# 3. 목적: 전략 수립
#    행동: 수집한 정보를 바탕으로 실행 가능한 전략과 방법론 설계
#    산출물: 전략 계획서 및 실행 방안
#    도구필요여부: 필요 (전략 기획 도구)
#    한줄 요약: 목표 달성을 위한 구체적인 전략을 수립한다.
#
# 4. 목적: 자원 및 역할 배분
#    행동: 필요한 자원과 인력을 파악하고 적절히 배분
#    산출물: 자원 배분 계획 및 역할 분담표
#    도구필요여부: 필요 (프로젝트 관리 도구)
#    한줄 요약: 효율적인 실행을 위해 자원과 역할을 체계적으로 배분한다.
#
# 5. 목적: 실행 및 모니터링
#    행동: 계획에 따라 실행하며 진행 상황을 지속적으로 점검
#    산출물: 실행 결과 보고서 및 피드백 자료
#    도구필요여부: 필요 (모니터링 도구)
#    한줄 요약: 계획을 실행하고 성과를 지속적으로 관리한다.
#
# 6. 목적: 평가 및 개선
#    행동: 실행 결과를 평가하고 문제점을 도출하여 개선안 마련
#    산출물: 평가 보고서 및 개선 계획서
#    도구필요여부: 필요 (분석 도구)
#    한줄 요약: 실행 결과를 평가하여 지속적으로 개선한다.
# ```
# ------------------------------ status ------------------------------
# planning
# ------------------------------ step ------------------------------
# 0
# ------------------------------ log ------------------------------
# ['[planner] 계획 설정']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 input = "로고 디자인을 위한 리서치"
# ----> 3 for evt in graph.stream({"messages" : [("user", input)]}, stream_mode="values"):
#       4     for key, value in evt.items():
#       5         print("-"*30, key,"-"*30)
#
# File c:\Potenup\LLM-Study\.venv\Lib\site-packages\langgraph\pregel\main.py:2674, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2672 for task in loop.match_cached_writes():
#    2673     loop.output_writes(task.id, task.writes, cached=True)
# -> 2674 for _ in runner.tick(
#    2675     [t for t in loop.tasks.values() if not t.writes],
#    2676     timeout=self.step_timeout,
#    2677     get_waiter=get_waiter,
#    2678     schedule_task=loop.accept_push,
#    2679 ):
#    2680     # emit output
#    2681     yield from _output(
#    2682         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2683     )
#    2684 loop.after_tick()
#
# File c:\Potenup\LLM-Study\.venv\Lib\site-packages\langgraph\pregel\_runner.py:162, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     160 t = tasks[0]
#     161 try:
# --> 162     run_with_retry(
#     163         t,
#     164         retry_policy,
#     165         configurable={
#     166             CONFIG_KEY_CALL: partial(
#     167                 _call,
#     168                 weakref.ref(t),
#     169                 retry_policy=retry_policy,
#     170                 futures=weakref.ref(futures),
#     171                 schedule_task=schedule_task,
#     172                 submit=self.submit,
#     173             ),
#     174         },
#     175     )
#     176     self.commit(t, None)
#     177 except Exception as exc:
#
# File c:\Potenup\LLM-Study\.venv\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Potenup\LLM-Study\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:657, in RunnableSeq.invoke(self, input, config, **kwargs)
#     655     # run in context
#     656     with set_config_context(config, run) as context:
# --> 657         input = context.run(step.invoke, input, config, **kwargs)
#     658 else:
#     659     input = step.invoke(input, config)
#
# File c:\Potenup\LLM-Study\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:401, in RunnableCallable.invoke(self, input, config, **kwargs)
#     399         run_manager.on_chain_end(ret)
#     400 else:
# --> 401     ret = self.func(*args, **kwargs)
#     402 if self.recurse and isinstance(ret, Runnable):
#     403     return ret.invoke(input, config)
#
# Cell In[7], line 11, in agent_node(state)
#       6 agent_system = (
#       7     "당신은 코딩/리서치/투자 어시스턴트야. 필요할 때 도구를 호출하고, 많은 내용이 담기면 요약해"
#       8     "너무 많은 말을 하지말고, 다음 행동을 분명히 하도록 해"
#       9 )
#      10 msg = [("system", agent_system), *state.get("messages", [])]
# ---> 11 out = agent.invoke({"messages", msg})
#      12 new = {**state, "status": "acting"}
#      13 new.setdefault("messages", []).extend(out["messages"])
#
# TypeError: unhashable type: 'list'
# During task with name 'agent' and id 'd6a3edd6-5878-e18e-ee82-cb2b4c93149b'
